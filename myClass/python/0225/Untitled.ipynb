# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# /home/student/mydev/my_practise/myclass/0225
# ['b1.html', 'download.jpeg', 'girl.jpg', 'girl2.jpg', 'temp.py', 'a12.html', 'Untitled.ipynb', '.ipynb_checkpoints']
