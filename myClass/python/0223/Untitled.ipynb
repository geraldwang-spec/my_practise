# %%
import os
print(os.getcwd())
# Out:
# /home/student/mydev/my_practise/myclass

# %%
os.listdir()
# Out:
# ['0223a.html',
#  'momo拷貝.jpg',
#  'test2拷貝.webp',
#  'momo.gif',
#  'download.jpeg',
#  'news.jpg',
#  '0225',
#  'Untitled.ipynb',
#  '.ipynb_checkpoints']
